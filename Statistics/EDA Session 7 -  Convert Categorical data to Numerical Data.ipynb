# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

fileName = "Visadataset.csv"
visa_df=pd.read_csv(fileName)

# %%
visa_df.corr(numeric_only=True)
# Out:
#                  no_of_employees  yr_of_estab  prevailing_wage
# no_of_employees         1.000000    -0.017770        -0.009523
# yr_of_estab            -0.017770     1.000000         0.012342
# prevailing_wage        -0.009523     0.012342         1.000000

# %%
# matrix 
# showing values in a matrix
# showing values in a picture: Heatmap

# %%
corr_data=visa_df.corr(numeric_only=True)
sns.heatmap(corr_data, annot=True)
# Out:
# <Axes: >

# %%
# winequality winequality_red

fileName="winequality_red.csv"
winequalityred_df=pd.read_csv(fileName)
winequalityred_df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  ...    pH  sulphates  alcohol  quality
# 0               NaN               NaN          NaN             NaN  ...   NaN        NaN      NaN      NaN
# 1               7.4             0.700         0.00             1.9  ...  3.51       0.56      9.4      5.0
# 2               NaN               NaN          NaN             NaN  ...   NaN        NaN      NaN      NaN
# 3               7.8             0.880         0.00             2.6  ...  3.20       0.68      9.8      5.0
# 4               NaN               NaN          NaN             NaN  ...   NaN        NaN      NaN      NaN
# ...             ...               ...          ...             ...  ...   ...        ...      ...      ...
# 3193            6.3             0.510         0.13             2.3  ...  3.42       0.75     11.0      6.0
# 3194            NaN               NaN          NaN             NaN  ...   NaN        NaN      NaN      NaN
# ...

# %%
corr_winequalityred = winequalityred_df.corr(numeric_only=True)
plt.figure(figsize=(10,10))
sns.heatmap(corr_winequalityred,annot=True)
# Out:
# <Axes: >

# %%
plt.scatter(winequalityred_df['fixed acidity'],winequalityred_df['citric acid'])

# %%
# Start Convertion of Categorical Data to Numberical Data
visa_df
# Out:
#          case_id continent education_of_employee  ... unit_of_wage full_time_position  case_status
# 0         EZYV01      Asia           High School  ...         Hour                  Y       Denied
# 1         EZYV02      Asia              Master's  ...         Year                  Y    Certified
# 2         EZYV03      Asia            Bachelor's  ...         Year                  Y       Denied
# 3         EZYV04      Asia            Bachelor's  ...         Year                  Y       Denied
# 4         EZYV05    Africa              Master's  ...         Year                  Y    Certified
# ...          ...       ...                   ...  ...          ...                ...          ...
# 25475  EZYV25476      Asia            Bachelor's  ...         Year                  Y    Certified
# 25476  EZYV25477      Asia           High School  ...         Year                  Y    Certified
# ...

# %% [markdown]
# - In machine learing algorithms will develop models using maths
#
# - Maths allows only numbers
#
# - So it is very important, you need to pass numerical data only
#
# - So we need to convert Categorical data to numerical data
#
# - For that we have encoding mathods
#
# - Encoding
#
#     - Lable encoder
#
#         - map method
#
#         - np.where
#
#         - LableEncoder package from sklearn
#
#     - One hot encoder
#
#         - pd.get_dummies()

# %% [markdown]
# $Method - 1: Map Method$

# %% [markdown]
# - Read any categorical column: Case_status
#
# - check how many unique lables are there
#
# - create a dictonary with those unique lable as Keys by provide number of the value

# %%
########## read te data ###################
visa_df

###########################################
visa_df['case_status'].unique()
dict1={'Certified':0,'Denied':1}
visa_df['case_status'].map(dict1)

# do you want override existed column
# do you want create a new column
# Out:
# 0        1
# 1        0
# 2        1
# 3        1
# 4        0
#         ..
# 25475    0
# 25476    0
# 25477    0
# 25478    0
# 25479    0
# Name: case_status, Length: 25480, dtype: int64

# %% [markdown]
# **Create a new column**

# %%
visa_df['case_status_num']=visa_df['case_status'].map(dict1)

# %%
visa_df
# Out:
#          case_id continent education_of_employee  ... full_time_position case_status  case_status_num
# 0         EZYV01      Asia           High School  ...                  Y      Denied                1
# 1         EZYV02      Asia              Master's  ...                  Y   Certified                0
# 2         EZYV03      Asia            Bachelor's  ...                  Y      Denied                1
# 3         EZYV04      Asia            Bachelor's  ...                  Y      Denied                1
# 4         EZYV05    Africa              Master's  ...                  Y   Certified                0
# ...          ...       ...                   ...  ...                ...         ...              ...
# 25475  EZYV25476      Asia            Bachelor's  ...                  Y   Certified                0
# 25476  EZYV25477      Asia           High School  ...                  Y   Certified                0
# ...

# %% [markdown]
# **Drop a case_status_num**

# %%
visa_df.drop('case_status_num', axis=1, inplace=True)

# %%
visa_df
# Out:
#          case_id continent education_of_employee  ... unit_of_wage full_time_position  case_status
# 0         EZYV01      Asia           High School  ...         Hour                  Y       Denied
# 1         EZYV02      Asia              Master's  ...         Year                  Y    Certified
# 2         EZYV03      Asia            Bachelor's  ...         Year                  Y       Denied
# 3         EZYV04      Asia            Bachelor's  ...         Year                  Y       Denied
# 4         EZYV05    Africa              Master's  ...         Year                  Y    Certified
# ...          ...       ...                   ...  ...          ...                ...          ...
# 25475  EZYV25476      Asia            Bachelor's  ...         Year                  Y    Certified
# 25476  EZYV25477      Asia           High School  ...         Year                  Y    Certified
# ...

# %% [markdown]
# **Override on same column**

# %%
########## read te data ###################
fileName = "Visadataset.csv"
visa_df=pd.read_csv(fileName)
visa_df

###########################################
visa_df['case_status'].unique()
dict1={'Certified':0,'Denied':1}
dict2={1:'Certified', 0:'Denied'}
visa_df['case_status']=visa_df['case_status'].map(dict1)
visa_df['case_status']
# Out:
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
#          ..
# 25475   NaN
# 25476   NaN
# 25477   NaN
# 25478   NaN
# 25479   NaN
# Name: case_status, Length: 25480, dtype: float64

# %%
dict2={1: 'Certified', 0: 'Denied'}
dict2
# Out:
# {1: 'Certified', 0: 'Denied'}

# %%
visa_df['case_status']
# Out:
# 0        0
# 1        1
# 2        0
# 3        0
# 4        1
#         ..
# 25475    1
# 25476    1
# 25477    1
# 25478    1
# 25479    1
# Name: case_status, Length: 25480, dtype: int64

# %%
fileName = "Visadataset.csv"
visa_df=pd.read_csv(fileName)
visa_df['case_status']
# Out:
# 0           Denied
# 1        Certified
# 2           Denied
# 3           Denied
# 4        Certified
#            ...
# 25475    Certified
# 25476    Certified
# 25477    Certified
# 25478    Certified
# 25479    Certified
# Name: case_status, Length: 25480, dtype: object

# %%
num=len(visa_df['continent'].unique())

dict1={}
for i in range(num):
        label=visa_df['continent'].unique()[i]
        dict1[label]=i
dict1
labels=visa_df['continent'].unique()
{labels[i]:i for i in range(num)}
# Out:
# {'Asia': 0,
#  'Africa': 1,
#  'North America': 2,
#  'Europe': 3,
#  'South America': 4,
#  'Oceania': 5}

# %% [markdown]
# $Method - 2 : np.where()$

# %%
############## Read the data again ########################
fileName = "Visadataset.csv"
visa_df=pd.read_csv(fileName)
visa_df['case_status']
# Out:
# 0           Denied
# 1        Certified
# 2           Denied
# 3           Denied
# 4        Certified
#            ...
# 25475    Certified
# 25476    Certified
# 25477    Certified
# 25478    Certified
# 25479    Certified
# Name: case_status, Length: 25480, dtype: object

# %% [markdown]
# - np.where() in only applicable for binary conditions
#
# - which means it is applicable only for two labels
#
# - np.where(<Condition>,<truevalue>,<Falsevalue>)

# %%
con=visa_df['case_status']=='Certified'
visa_df['case_status']=np.where(con,0,1)
visa_df
# Out:
#          case_id continent education_of_employee  ... unit_of_wage full_time_position  case_status
# 0         EZYV01      Asia           High School  ...         Hour                  Y            1
# 1         EZYV02      Asia              Master's  ...         Year                  Y            1
# 2         EZYV03      Asia            Bachelor's  ...         Year                  Y            1
# 3         EZYV04      Asia            Bachelor's  ...         Year                  Y            1
# 4         EZYV05    Africa              Master's  ...         Year                  Y            1
# ...          ...       ...                   ...  ...          ...                ...          ...
# 25475  EZYV25476      Asia            Bachelor's  ...         Year                  Y            1
# 25476  EZYV25477      Asia           High School  ...         Year                  Y            1
# ...

# %% [markdown]
# $LabelEncoder$

# %% [markdown]
# - LableEncoder is a method from sklearn
#
# - Under sklearn we have sub modules
#
# - one of the submodule: preprocessing
#
# - Any sklearn packages we have only 3 steps
#
# - Step-1: Read the Package
#
# - Step-2: Save the Package
#
# - Step-3: Apply fit treansfotm

# %%
############## Read the data again ########################
fileName = "Visadataset.csv"
visa_df=pd.read_csv(fileName)

#Step-1
from sklearn.preprocessing import LabelEncoder

#Step-2
le=LabelEncoder()

#Step-3
visa_df['case_status']=le.fit_transform(visa_df['case_status'])
visa_df['case_status']

visa_df['continent']=le.fit_transform(visa_df['continent'])
# Out:
# array([1, 0, 3, 2, 5, 4])

# %% [markdown]
# **fit_transform:**
# - fit and transform two different definations
#
# age:
# 1
# 2
# 3
# 4
# 5
#
# new age: by adding each observation with mean value: x+mean
#
# mean: 1+2+3+4+5/5=3  ============= fit
#
# New age: ========================= transform
#
# 1+3
#
# 2+3
#
# 3+3
#
# 4+3
#
# 5+3

# %%
visa_df['continent'].unique()
# Out:
# array([1, 0, 3, 2, 5, 4])

# %%
visa_df['continent'][:5]
# Out:
# 0    1
# 1    1
# 2    1
# 3    1
# 4    0
# Name: continent, dtype: int32

# %%
le.inverse_transform(visa_df['continent'])
# Out:
# array(['Asia', 'Asia', 'Asia', ..., 'Asia', 'Asia', 'Asia'], dtype=object)

# %% [markdown]
# **One hot Encoder**

# %% [markdown]
# - one hot encoder means at a time only one will be ON(1/True), other are OFF(0/False)
#
# -
#
# - In one ho encoder it will create two new column
#
# - like below
#
#     |Case_status|Certified|Denied|
#     |-----------|---------|------|
#     |Certified  |   1     |  0   |
#     |Denied     |   0     |  1   |
#
# **Advantage**
#
# - one hot encoder new columns are Orthogonality each other
#
# - Orthogonality means 90 degress phase shift
#
# - 90 degress phase shift means perpendicular each other
#
# - perpendicular means independent each other
#
# - Independent means no relation
#
# - It is very important property that is to avoid relation between variables
#
# **Draw back:**
#
# - Assume that you have 100 unique labels for a column
#
# - So it will create 100 new column
#
# - To process 100 column we require more memory, more time more hardware
#
# - This is called **Curse of Dimensionality**

# %% [markdown]
# **pd.get_dummies**

# %%
pd.get_dummies(visa_df, columns=['case_status'])
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
pd.get_dummies(visa_df, 
               columns=['continent'],
               dtype='int')
# Out:
#          case_id education_of_employee has_job_experience  \
# 0         EZYV01           High School                  N
# 1         EZYV02              Master's                  Y
# 2         EZYV03            Bachelor's                  N
# 3         EZYV04            Bachelor's                  N
# 4         EZYV05              Master's                  Y
# ...          ...                   ...                ...
# 25475  EZYV25476            Bachelor's                  Y
# 25476  EZYV25477           High School                  Y
# 25477  EZYV25478              Master's                  Y
# 25478  EZYV25479              Master's                  Y
# 25479  EZYV25480            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# 1                         N             2412         2002
# 2                         Y            44444         2008
# ...

# %%
pd.get_dummies(visa_df, 
               columns=['case_status'],
               dtype='int')
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...
