# %%
*********EDA************
1) pandas: datatrame analysis
2) numpy : Numerical python/Number Python
3) matplotlib: plot
4) seaborn:
5) plotly:
6) bokhe:
    
*********ML************
7) scikit-learn:
*********DL************
8) tensorflow:
9) keras
10) pytorch
11) cv (computer vision)
*********NLP***********
12) nltk
13) scipy
********Generative AI*******
14) chatGPT : openAI
15) makersuit: google Gen AI
16)Amazon Q : Amazon
*********Hugging face transformer (BERT)*********
17) Transformers
*********Other*********
random
math
os
sys
time
*********Azure ML*******
Azure packages
Gcp vertex ai
aws sage maker

# %% [markdown]
# $Step- 1$
# #### Import required packages

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %% [markdown]
# $Step - 2$
# ### Read the Data
#
# visadataset

# %%
file_path="C:\\Users\\DELL\\Documents\\Naresh IT\\Data Science\\Classes\\Statistics\\Visadataset.csv"

pd.read_csv(file_path)
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
file_path="C:\\Users\\DELL\\Documents\\Naresh IT\\Data Science\\Classes\\Statistics\\bank.csv"
pd.read_csv(file_path)
# Out:
#       age            job  marital  education default  balance housing loan  \
# 0      30     unemployed  married    primary      no     1787      no   no
# 1      33       services  married  secondary      no     4789     yes  yes
# 2      35     management   single   tertiary      no     1350     yes   no
# 3      30     management  married   tertiary      no     1476     yes  yes
# 4      59    blue-collar  married  secondary      no        0     yes   no
# ...   ...            ...      ...        ...     ...      ...     ...  ...
# 4516   33       services  married  secondary      no     -333     yes   no
# 4517   57  self-employed  married   tertiary     yes    -3313     yes  yes
# 4518   57     technician  married  secondary      no      295      no   no
# 4519   28    blue-collar  married  secondary      no     1137      no   no
# 4520   44   entrepreneur   single   tertiary      no     1136     yes  yes
#
# ...

# %% [markdown]
# $Step - 3$
#
# **Create a dataframe using lists**

# %%
list1=['Ram','Raheem','Robert']
list2=[30,31,32]
names=pd.DataFrame(zip(list1,list2),
             columns=['Name','Age'])

# %%
names
# Out:
#      Name  Age
# 0     Ram   30
# 1  Raheem   31
# 2  Robert   32

# %% [markdown]
# $Step-4$
#
# **How to save the dataframe in local**

# %%
######### M1 ###############
file_path="C:\\Users\\DELL\\Documents\\Naresh IT\\Data Science\\Classes\\Statistics\\names.csv"
names.to_csv(file_path)
pd.read_csv(file_path)
# Out:
#    Unnamed: 0    Name  Age
# 0           0     Ram   30
# 1           1  Raheem   31
# 2           2  Robert   32

# %%
######### M2 ##############
file_name="new_names.csv"
names.to_csv(file_name)

# %%
######### M3 ##############
file_name="new_names1.csv"
names.to_csv(file_name,index=False)

# %%
file_name="new_names.csv"
pd.read_csv(file_name)
# Out:
#    Unnamed: 0    Name  Age
# 0           0     Ram   30
# 1           1  Raheem   31
# 2           2  Robert   32

# %%
file_name="new_names1.csv"
pd.read_csv(file_name)
# Out:
#      Name  Age
# 0     Ram   30
# 1  Raheem   31
# 2  Robert   32

# %%
os.getcwd()
# Out:
# 'C:\\Users\\DELL\\Documents\\Naresh IT\\Data Science\\Classes\\Statistics'

# %%
names.sum()
# Out:
# Name    RamRaheemRobert
# Age                  93
# dtype: object

# %%
# how can remove unnamed 0

# %% [markdown]
# $step-5$
#
# **Add a new cloumn to existing dataframe**

# %%
names
# Out:
#      Name  Age
# 0     Ram   30
# 1  Raheem   31
# 2  Robert   32

# %%
#what is the data frame name
#what is the name of the new cloumn

# %%
names['city']=['Hyd','Chennai','Blr']

# %%
names
# Out:
#      Name  Age     city
# 0     Ram   30      Hyd
# 1  Raheem   31  Chennai
# 2  Robert   32      Blr

# %% [markdown]
# $Step-6$
#
# **How to drop the cloumn**

# %%
# What is your data frame name
********Axis***************
# I want to drop cloumns
# axis=1 ======= cloumns
# axis=0 ======= Rows
****************************
# what is the name of the cloumn 
********inplace**************
# when you are drop the cloumn means
#      you are modifying the table
#
# you want to create a dataframe
# inplace=True : data will be overwrite

# %%
names.drop('city',axis=1,inplace=True)

# %%
names
# Out:
#      Name  Age
# 0     Ram   30
# 1  Raheem   31
# 2  Robert   32

# %%
dict1={'Names':['Ram','Raheem','Robert'],
      'Age':[30,31,32]}

# %%
dict1
# Out:
# {'Names': ['Ram', 'Raheem', 'Robert'], 'Age': [30, 31, 32]}

# %%
pd.DataFrame(dict1)
# Out:
#     Names  Age
# 0     Ram   30
# 1  Raheem   31
# 2  Robert   32

# %%
pd.DataFrame(dict1,columns=['A','B'])
# Out:
# Empty DataFrame
# Columns: [A, B]
# Index: []

# %%
pd.DataFrame(dict1, index=['A','B','C'])
# Out:
#     Names  Age
# A     Ram   30
# B  Raheem   31
# C  Robert   32
